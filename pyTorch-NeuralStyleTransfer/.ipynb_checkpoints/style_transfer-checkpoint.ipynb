# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torchvision.models as models
import os
import copy
from helper import *

# %%
style_img = image_loader("style12.png")
content_img = image_loader("ATD-AA.png",h=False)
plt.ion()

plt.figure()
imshow(style_img, title='Style Image')

plt.figure()
imshow(content_img, title='Content Image')

# %%
cnn = models.vgg19(pretrained=True).features.to(device).eval()
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
cnn_normalization_std = torch.tensor([0.229, 0.224, 0.225]).to(device)
input_img = content_img.clone()

# %%
input_img.shape
# Out:
# torch.Size([1, 4, 3115, 1024])

# %%
content_img.shape
# Out:
# torch.Size([1, 4, 3115, 1024])

# %%
style_img.shape
# Out:
# torch.Size([1, 3, 1416, 1024])

# %%
# desired depth layers to compute style/content losses :
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

# %%
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style_img, input_img,content_layers_default,style_layers_default)
# Out:
# Building the style transfer model..
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-3d6efb935867> in <module>()
#       1 output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
# ----> 2                             content_img, style_img, input_img,content_layers_default,style_layers_default)
#
# ~/Documents/Projects/tech_blog/pyTorch-NeuralStyleTransfer/helper.py in run_style_transfer(cnn, normalization_mean, normalization_std, content_img, style_img, input_img, content_layers, style_layers, num_steps, style_weight, content_weight)
#     128     model, style_losses, content_losses = get_style_model_and_losses(cnn,
#     129         normalization_mean, normalization_std, style_img, content_img,content_layers,
# --> 130                                style_layers)
#     131     optimizer = get_input_optimizer(input_img)
#     132
#
# ~/Documents/Projects/tech_blog/pyTorch-NeuralStyleTransfer/helper.py in get_style_model_and_losses(cnn, normalization_mean, normalization_std, style_img, content_img, content_layers, style_layers)
#      93         if name in content_layers:
#      94             # add content loss:
# ---> 95             target = model(content_img).detach()
#      96             content_loss = ContentLoss(target)
#      97             model.add_module("content_loss_{}".format(i), content_loss)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# /usr/local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/Documents/Projects/tech_blog/pyTorch-NeuralStyleTransfer/helper.py in forward(self, img)
#     209     def forward(self, img):
#     210         # normalize img
# --> 211         return (img - self.mean) / self.std
#
# RuntimeError: The size of tensor a (4) must match the size of tensor b (3) at non-singleton dimension 1

# %%
plt.figure(figsize = (20,10))
imshow(output, title='Output Image')

# sphinx_gallery_thumbnail_number = 4
plt.ioff()
plt.show()
